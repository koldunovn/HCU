# %% [markdown]
# #Missing values

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from netCDF4 import Dataset

# %%
f = Dataset('../Week8/model_temp_time.nc4')

# %%
temp = f.variables['temp'][:]

# %%
temp.shape
# Out:
# (5, 9, 416, 480)

# %%
plt.imshow(temp[0,0,:,:])

# %% [markdown]
# What are this white areas?

# %%
one_field = temp[0,0,:,:]

# %%
plt.imshow(one_field)

# %%
one_field[400,400]
# Out:
# masked

# %%
one_field
# Out:
# masked_array(data =
#  [[-- -- -- ..., -- -- --]
#  [-- -- -- ..., -- -- --]
#  [-- -- -- ..., -- -- --]
#  ...,
#  [-- -- -- ..., -- -- --]
#  [-- -- -- ..., -- -- --]
#  [-- -- -- ..., -- -- --]],
#              mask =
#  [[ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  ...,
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]],
#        fill_value = -1e+23)

# %%
type(one_field)
# Out:
# numpy.ma.core.MaskedArray

# %%
plt.imshow(one_field[325:335,385:390])

# %%
one_field[325:335,385:390].mask
# Out:
# array([[ True, False, False, False, False],
#        [ True,  True,  True, False, False],
#        [ True,  True, False, False, False],
#        [ True,  True,  True, False, False],
#        [ True,  True,  True,  True, False],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True]], dtype=bool)

# %%
plt.pcolormesh(np.flipud(one_field[325:335,385:390]))

# %%
b_masked = one_field[325:335,385:390]

# %%
b_masked
# Out:
# masked_array(data =
#  [[-- -1.6315103769302368 -1.624253749847412 -1.6130439043045044
#   -1.6257729530334473]
#  [-- -- -- -1.6174774169921875 -1.6417274475097656]
#  [-- -- -1.5885295867919922 -1.6177394390106201 -1.625877022743225]
#  [-- -- -- -1.616289734840393 -1.5797284841537476]
#  [-- -- -- -- -1.5458563566207886]
#  [-- -- -- -- --]
#  [-- -- -- -- --]
#  [-- -- -- -- --]
#  [-- -- -- -- --]
#  [-- -- -- -- --]],
#              mask =
#  [[ True False False False False]
#  [ True  True  True False False]
#  [ True  True False False False]
#  [ True  True  True False False]
#  [ True  True  True  True False]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]
#  [ True  True  True  True  True]],
#        fill_value = -1e+23)

# %% [markdown]
# ##Why we need masked arrays?

# %% [markdown]
# Usually data that you get will look like this:

# %%
usuall_mask = np.ma.filled(b_masked, fill_value=-999)
usuall_mask
# Out:
# array([[-999.   ,   -1.632,   -1.624,   -1.613,   -1.626],
#        [-999.   , -999.   , -999.   ,   -1.617,   -1.642],
#        [-999.   , -999.   ,   -1.589,   -1.618,   -1.626],
#        [-999.   , -999.   , -999.   ,   -1.616,   -1.58 ],
#        [-999.   , -999.   , -999.   , -999.   ,   -1.546],
#        [-999.   , -999.   , -999.   , -999.   , -999.   ],
#        [-999.   , -999.   , -999.   , -999.   , -999.   ],
#        [-999.   , -999.   , -999.   , -999.   , -999.   ],
#        [-999.   , -999.   , -999.   , -999.   , -999.   ],
#        [-999.   , -999.   , -999.   , -999.   , -999.   ]], dtype=float32)

# %% [markdown]
# ##Exersise
#
# - Calculate temperature mean in `ussuall_mask`

# %%
one_field[300,200]
# Out:
# -1.7368417

# %%
one_field[300:302,300:302].mask
# Out:
# array([[False, False],
#        [False, False]], dtype=bool)

# %%
o

# %%
ls ../Week8
# Out:
# 2darray.npy  2dbase4.png  3darray.npy  3dbase2.png  3dbase.png   4dbase3.png  4dshape.png       model_temp_time.nc4
# 2dbase1.png  2dbase5.png  3darray.png  3dbase3.png  4darray.npy  4dbase4.png  5dbase.png        Untitled0.ipynb
# 2dbase2.png  2dbase6.png  3darray.xcf  3dbase4.png  4dbase1.png  4dbase5.png  5shape.png        yBG6h.jpg
# 2dbase3.png  2dbase.png   3dbase1.png  3dbase5.png  4dbase2.png  4dbase.png   anatomyarray.png

# %%
a = np.random.random_integers(0,10, (100,100))
a
# Out:
# array([[ 9, 10,  1, ...,  0,  8,  1],
#        [ 1,  5,  7, ...,  2,  2,  1],
#        [ 7,  0, 10, ...,  6,  8,  4],
#        ...,
#        [ 5,  4,  4, ...,  8,  2, 10],
#        [ 7,  7,  6, ...,  2,  0,  0],
#        [ 0,  7,  8, ...,  0,  3, 10]])

# %%
a.shape
# Out:
# (100, 100)

# %%
plt.imshow(a)
