# %%
from netCDF4 import Dataset
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np

# %%
#!wget https://dl.dropboxusercontent.com/u/107639/curv_grid.nc

# %%
f = Dataset('model_temp_time.nc4')

# %%
plt.imshow(np.flipud(f.variables['temp'][0,0,:,:]))

# %% [markdown]
# ##Exersise
#
# - Find out how many variables are in the netCDF file
# - What shape variable `temp` have?
# - How many dimensions variable `temp` have?
# - What each dimension mean?

# %%
temp = f.variables['temp']

# %% [markdown]
# #Once again arrays

# %% [markdown]
# <img src='anatomyarray.png'>

# %%
a = np.load('2darray.npy')

# %%
a
# Out:
# array([[3, 6, 2, 1, 7],
#        [4, 1, 3, 2, 8],
#        [7, 9, 2, 1, 8],
#        [8, 6, 9, 6, 7],
#        [9, 1, 9, 2, 6],
#        [9, 8, 1, 5, 6],
#        [0, 4, 2, 0, 6],
#        [0, 3, 1, 4, 7]])

# %%
a.shape
# Out:
# (8, 5)

# %% [markdown]
# ##Exersise
#
# Select slices from array

# %% [markdown]
# <img src='2dbase1.png', width="300">

# %% [markdown]
# <img src='2dbase2.png', width="300">

# %% [markdown]
# <img src='2dbase3.png', width="300">

# %% [markdown]
# <img src='2dbase4.png', width="300">

# %% [markdown]
# <img src='2dbase5.png', width="300">

# %% [markdown]
# <img src='2dbase6.png', width="300">

# %%
plt.imshow(a)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f5cd555e248>

# %%
plt.pcolormesh(a)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f5cd510a0e0>

# %%
a3 = np.load('3darray.npy')

# %%
a3
# Out:
# array([[[3, 6, 2, 1, 7],
#         [4, 1, 3, 2, 8],
#         [7, 9, 2, 1, 8],
#         [8, 6, 9, 6, 7],
#         [9, 1, 9, 2, 6],
#         [9, 8, 1, 5, 6],
#         [0, 4, 2, 0, 6],
#         [0, 3, 1, 4, 7]],
#
#        [[5, 5, 3, 9, 3],
#         [8, 3, 5, 1, 1],
#         [3, 4, 3, 0, 9],
#         [1, 4, 1, 0, 2],
#         [7, 1, 2, 0, 1],
#         [5, 1, 3, 7, 8],
#         [8, 0, 9, 6, 0],
#         [7, 7, 4, 4, 4]],
#
#        [[1, 0, 8, 9, 1],
#         [7, 4, 8, 8, 2],
#         [9, 1, 8, 3, 6],
#         [5, 6, 2, 0, 1],
#         [7, 4, 2, 5, 7],
#         [9, 5, 6, 8, 6],
#         [7, 4, 4, 7, 1],
#         [8, 4, 4, 9, 1]]])

# %%
a3.shape
# Out:
# (3, 8, 5)

# %% [markdown]
# <img src='3darray.png' width="300">

# %% [markdown]
# ##Exersise

# %% [markdown]
# <img src='3dbase1.png', width="300">

# %% [markdown]
# <img src='3dbase2.png', width="300">

# %% [markdown]
# <img src='3dbase3.png', width="300">

# %% [markdown]
# <img src='3dbase4.png', width="300">

# %% [markdown]
# <img src='3dbase5.png', width="300">

# %% [markdown]
# ##Exersise
#
#  - Plot one of the `depth` levels of `a3` (use imshow and pcolormesh)
#  - Plot last (#4) column over `depth` (use imshow and pcolormesh)

# %%
a4 = np.load('4darray.npy')

# %%
a4
# Out:
# array([[[[3, 6, 2, 1, 7],
#          [4, 1, 3, 2, 8],
#          [7, 9, 2, 1, 8],
#          [8, 6, 9, 6, 7],
#          [9, 1, 9, 2, 6],
#          [9, 8, 1, 5, 6],
#          [0, 4, 2, 0, 6],
#          [0, 3, 1, 4, 7]],
#
#         [[5, 5, 3, 9, 3],
#          [8, 3, 5, 1, 1],
#          [3, 4, 3, 0, 9],
#          [1, 4, 1, 0, 2],
#          [7, 1, 2, 0, 1],
#          [5, 1, 3, 7, 8],
#          [8, 0, 9, 6, 0],
#          [7, 7, 4, 4, 4]],
#
#         [[1, 0, 8, 9, 1],
#          [7, 4, 8, 8, 2],
#          [9, 1, 8, 3, 6],
#          [5, 6, 2, 0, 1],
#          [7, 4, 2, 5, 7],
#          [9, 5, 6, 8, 6],
#          [7, 4, 4, 7, 1],
#          [8, 4, 4, 9, 1]]],
#
#
#        [[[3, 6, 2, 1, 7],
#          [4, 1, 3, 2, 8],
#          [7, 9, 2, 1, 8],
#          [8, 6, 9, 6, 7],
#          [9, 1, 9, 2, 6],
#          [9, 8, 1, 5, 6],
#          [0, 4, 2, 0, 6],
#          [0, 3, 1, 4, 7]],
#
#         [[5, 5, 3, 9, 3],
#          [8, 3, 5, 1, 1],
#          [3, 4, 3, 0, 9],
#          [1, 4, 1, 0, 2],
#          [7, 1, 2, 0, 1],
#          [5, 1, 3, 7, 8],
#          [8, 0, 9, 6, 0],
#          [7, 7, 4, 4, 4]],
#
#         [[1, 0, 8, 9, 1],
#          [7, 4, 8, 8, 2],
#          [9, 1, 8, 3, 6],
#          [5, 6, 2, 0, 1],
#          [7, 4, 2, 5, 7],
#          [9, 5, 6, 8, 6],
#          [7, 4, 4, 7, 1],
#          [8, 4, 4, 9, 1]]],
#
#
#        [[[3, 6, 2, 1, 7],
#          [4, 1, 3, 2, 8],
#          [7, 9, 2, 1, 8],
#          [8, 6, 9, 6, 7],
#          [9, 1, 9, 2, 6],
#          [9, 8, 1, 5, 6],
#          [0, 4, 2, 0, 6],
#          [0, 3, 1, 4, 7]],
#
#         [[5, 5, 3, 9, 3],
#          [8, 3, 5, 1, 1],
#          [3, 4, 3, 0, 9],
#          [1, 4, 1, 0, 2],
#          [7, 1, 2, 0, 1],
#          [5, 1, 3, 7, 8],
#          [8, 0, 9, 6, 0],
#          [7, 7, 4, 4, 4]],
#
#         [[1, 0, 8, 9, 1],
#          [7, 4, 8, 8, 2],
#          [9, 1, 8, 3, 6],
#          [5, 6, 2, 0, 1],
#          [7, 4, 2, 5, 7],
#          [9, 5, 6, 8, 6],
#          [7, 4, 4, 7, 1],
#          [8, 4, 4, 9, 1]]]])

# %% [markdown]
# #4d array
# <img src='4dbase.png' width="800">
#
# <img src='4dshape.png' width="200">

# %% [markdown]
# ##Exersise

# %% [markdown]
# <img src='4dbase1.png' width="800">

# %% [markdown]
# <img src='4dbase2.png' width="800">

# %% [markdown]
# <img src='4dbase3.png' width="800">

# %% [markdown]
# <img src='4dbase4.png' width="800">

# %% [markdown]
# <img src='4dbase5.png' width="800">

# %% [markdown]
# ##Exersise
#
#  - Plot last time step of the 0 `depth` levels of `a4` (use imshow and pcolormesh)

# %% [markdown]
# #5d array

# %% [markdown]
# <img src='5dbase.png' width="400">

# %%
a3 = np.random.randint(0,10,size=(3,8,5))

# %%
a3[0,:,:]=a
a3
# Out:
# array([[[3, 6, 2, 1, 7],
#         [4, 1, 3, 2, 8],
#         [7, 9, 2, 1, 8],
#         [8, 6, 9, 6, 7],
#         [9, 1, 9, 2, 6],
#         [9, 8, 1, 5, 6],
#         [0, 4, 2, 0, 6],
#         [0, 3, 1, 4, 7]],
#
#        [[5, 5, 3, 9, 3],
#         [8, 3, 5, 1, 1],
#         [3, 4, 3, 0, 9],
#         [1, 4, 1, 0, 2],
#         [7, 1, 2, 0, 1],
#         [5, 1, 3, 7, 8],
#         [8, 0, 9, 6, 0],
#         [7, 7, 4, 4, 4]],
#
#        [[1, 0, 8, 9, 1],
#         [7, 4, 8, 8, 2],
#         [9, 1, 8, 3, 6],
#         [5, 6, 2, 0, 1],
#         [7, 4, 2, 5, 7],
#         [9, 5, 6, 8, 6],
#         [7, 4, 4, 7, 1],
#         [8, 4, 4, 9, 1]]])

# %%
a = np.random.randint(0,10,size=(8,5))
a
# Out:
# array([[3, 6, 2, 1, 7],
#        [4, 1, 3, 2, 8],
#        [7, 9, 2, 1, 8],
#        [8, 6, 9, 6, 7],
#        [9, 1, 9, 2, 6],
#        [9, 8, 1, 5, 6],
#        [0, 4, 2, 0, 6],
#        [0, 3, 1, 4, 7]])

# %%
np.save('4darray', a4)
